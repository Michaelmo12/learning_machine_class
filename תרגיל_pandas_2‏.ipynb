# %% [markdown]
# <a href="https://colab.research.google.com/github/MichaelBuster/learning_machine_class/blob/main/%D7%AA%D7%A8%D7%92%D7%99%D7%9C_pandas_2%E2%80%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv('/content/students.csv.zip')
print(df)
# Out:
#     student_age  hours_of_study  grade
# 0             6               1     95
# 1             9               2     90
# 2            12               2     80
# 3            15               2     70
# 4            15               4     85
# 5            15               4     94
# 6            15               4     83
# 7            16               3     66
# 8            18              10     34
# 9            18               2     88
# 10           18               7     76
# 11           21               3     87
# 12           22               6     52
# 13           27               2     94
# 14           28               9     53
# 15           26              10    100
# 16           28              12     54
# 17           25               8     72
# 18           24              12     96
# 19           22              12     84

# %%
passed_students = df[df['grade'] > 55]
passed_students
# Out:
#     student_age  hours_of_study  grade
# 0             6               1     95
# 1             9               2     90
# 2            12               2     80
# 3            15               2     70
# 4            15               4     85
# 5            15               4     94
# 6            15               4     83
# 7            16               3     66
# 9            18               2     88
# 10           18               7     76
# 11           21               3     87
# 13           27               2     94
# 15           26              10    100
# 17           25               8     72
# 18           24              12     96
# 19           22              12     84

# %%
passed_students2 = df[(df['grade'] < 55) & (df['student_age'] > 25)]
passed_students2
# Out:
#     student_age  hours_of_study  grade
# 14           28               9     53
# 16           28              12     54

# %%
import matplotlib.pyplot as plt # Import matplotlib for plotting

# Assuming 'df' is your DataFrame and contains columns 'student_age' and 'hours_of_study'
plt.figure(figsize=(8, 6))  # Adjust figure size if needed
plt.scatter(df['student_age'], df['hours_of_study'])  # Create a scatter plot
plt.xlabel("student_age")  # X-axis label in Hebrew
plt.ylabel("hours_of_study")  # Y-axis label in Hebrew
plt.title("גיל הסטודנט מול סך השעות שלמד")  # Plot title in Hebrew
plt.grid(True)  # Add grid lines
plt.show()  # Display the plot

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # Import for 3D plotting

# Filter data for students who studied at least 3 hours
filtered_df = df[df['hours_of_study'] >= 3]

# Create the 3D plot
fig = plt.figure(figsize=(10, 8))  # Adjust figure size if needed
ax = fig.add_subplot(111, projection='3d')  # Create a 3D subplot

# Plot the data
ax.scatter(filtered_df['student_age'], filtered_df['hours_of_study'], filtered_df['grade'])

# Set labels (Hebrew)
ax.set_xlabel("student_age", fontsize=12)
ax.set_ylabel("hours_of_study", fontsize=12)
ax.set_zlabel("grade", fontsize=12)
ax.set_title("גיל, שעות לימוד וציון (לסטודנטים שלמדו לפחות 3 שעות)", fontsize=14)

plt.show()

# %%
avg_grade = df['grade'].mean()

# Create the 'grade_improve' column
df['grade_improve'] = df['grade'].apply(lambda grade: avg_grade if grade < avg_grade else grade)

# Display the updated DataFrame
df
# Out:
#     student_age  hours_of_study  grade  grade_improve
# 0             6               1     95          95.00
# 1             9               2     90          90.00
# 2            12               2     80          80.00
# 3            15               2     70          77.65
# 4            15               4     85          85.00
# 5            15               4     94          94.00
# 6            15               4     83          83.00
# 7            16               3     66          77.65
# 8            18              10     34          77.65
# 9            18               2     88          88.00
# 10           18               7     76          77.65
# 11           21               3     87          87.00
# 12           22               6     52          77.65
# 13           27               2     94          94.00
# 14           28               9     53          77.65
# 15           26              10    100         100.00
# ...
